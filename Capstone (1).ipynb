# %% [markdown]
# # Coursera Ibm Datascience Pro Certificate

# %% [markdown]
# Week 1
# ### Capstone Notebook

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# WEEK 4
#
# ## C@pstone Project
# ### Travel agency consultant   (Best Place in Rome)

# %% [markdown]
# #####  Introduction

# %% [markdown]
# Rome (Latin and Italian: Roma) is the capital city and a special comune of Italy). Rome also serves as the capital of the Lazio region. With 2,872,800 residents in 1,285 km2 (496.1 sq mi).It is the fourth most populous city in the European Union by population within city limits. It is the centre of the Metropolitan City of Rome, which has a population of 4,355,725 residents, thus making it the most populous metropolitan city in Italy.Rome is located in the central-western portion of the Italian Peninsula, within Lazio (Latium), along the shores of the Tiber. The Vatican City (the smallest country in the world)is an independent country inside the city boundaries of Rome, the only existing example of a country within a city: for this reason Rome has been often defined as capital of two states.
#
# Rome's history spans 28 centuries. While Roman mythology dates the founding of Rome at around 753 BC, the site has been inhabited for much longer, making it one of the oldest continuously occupied sites in Europe. It was first called The Eternal City (Latin: Urbs Aeterna; Italian: La Città Eterna) by the Roman poet Tibullus in the 1st century BC, and the expression was also taken up by Ovid, Virgil, and Livy.Rome is also called the "Caput Mundi" (Capital of the World). After the fall of the Western Empire, which marked the beginning of the Middle Ages, Rome slowly fell under the political control of the Papacy, and in the 8th century it became the capital of the Papal States, which lasted until 1870. Beginning with the Renaissance, almost all the popes since Nicholas V (1447–1455) pursued over four hundred years a coherent architectural and urban programme aimed at making the city the artistic and cultural centre of the world. In this way, Rome became first one of the major centres of the Italian Renaissance, and then the birthplace of both the Baroque style and Neoclassicism. Famous artists, painters, sculptors and architects made Rome the centre of their activity, creating masterpieces throughout the city. In 1871, Rome became the capital of the Kingdom of Italy, which, in 1946, became the Italian Republic.

# %% [markdown]
# #####  Business Problem

# %% [markdown]
# From consulting companies we are required by a group of tour operators to provide some well-defined program that allows these tourist agencies to create a series of tourist packages to be provided to their customers, in particular we are required to provide specific information about:
#
# - Historycal place to visit
# - Restaurant for typical food
# - Good accomodation Hotel
# - Spa and Wealth center Centro Benessere

# %% [markdown]
# #####  Data

# %% [markdown]
# The information will be extrapolated mainly from 3 sources:
#
# - Foursquare api
# - Wikipedia
# - csv.dataframe
#
# this thata will usefull for fit the better solution for the client

# %% [markdown]
# WEEK 5
# - precoding process

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

print('Library II imported .')
# Out:
# Library II imported .

# %%
from bs4 import BeautifulSoup
print ("Done")
# Out:
# Done

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '0FPIW43I0WQB4B31BTWLQKS4AZL4UCAYSMVSI1TKGLCTALB5' # your Foursquare ID
CLIENT_SECRET = 'PBQP2BNZO52VJEVFBW34V2WKWYLUZVCCNV1PKUKCU0SE2GYI' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Log-in, done!')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Log-in, done!
# CLIENT_ID: 0FPIW43I0WQB4B31BTWLQKS4AZL4UCAYSMVSI1TKGLCTALB5
# CLIENT_SECRET:PBQP2BNZO52VJEVFBW34V2WKWYLUZVCCNV1PKUKCU0SE2GYI

# %% [markdown]
# ##### Define City Target

# %%
address = ', Roma, RM'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.894802 12.4853384

# %% [markdown]
# Search for Interest Venue I Hotel

# %%
search_query = 'Hotel'
radius = 100000
print(search_query + ' .... OK!')
# Out:
# Hotel .... OK!

# %% [markdown]
# define URl

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0FPIW43I0WQB4B31BTWLQKS4AZL4UCAYSMVSI1TKGLCTALB5&client_secret=PBQP2BNZO52VJEVFBW34V2WKWYLUZVCCNV1PKUKCU0SE2GYI&ll=41.894802,12.4853384&v=20180604&query=Hotel&radius=100000&limit=30'

# %% [markdown]
# request and get results for search I

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5189eddb1d8100333ba2be'},
#  'response': {'venues': [{'id': '4adcdabff964a520735121e3',
#     'name': 'Hotel Pace Helvezia',
#     'location': {'address': 'Via 4 Novembre 104',
#      'lat': 41.896886831755005,
#      'lng': 12.484983726163296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.896886831755005,
#        'lng': 12.484983726163296}],
#      'distance': 233,
#      'postalCode': '00187',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via 4 Novembre 104', '00187 Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565624813',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframeHotel = json_normalize(venues)
dataframeHotel.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 5  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 6  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 7  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 8  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 9  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id            location.address location.cc  \
# 0  4adcdabff964a520735121e3          Via 4 Novembre 104          IT
# 1  4c0c1a17a1b32d7f830f9cf0           Via Frangipane 34          IT
# 2  4ba5f478f964a520182b39e3       Via Tor De' Conti, 25          IT
# ...

# %%
dataframeHotel.shape
# Out:
# (30, 18)

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f45bc30a5e1b> in <module>
#       1 # keep only columns that include venue name, and anything that is associated with location
# ----> 2 filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
#       3 dataframe_filtered = dataframe.loc[:, filtered_columns]
#       4
#       5 # function that extracts the category of the venue
#
# NameError: name 'dataframe' is not defined

# %%
dataframe_filtered.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-a8d2e6052617> in <module>
# ----> 1 dataframe_filtered.name
#
# NameError: name 'dataframe_filtered' is not defined

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-84dd12227b0f> in <module>
#      13
#      14 # add the Italian restaurants as blue circle markers
# ---> 15 for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
#      16     folium.features.CircleMarker(
#      17         [lat, lng],
#
# NameError: name 'dataframe_filtered' is not defined

# %% [markdown]
# Search for Interest Venue II Restaurant

# %%
search_query = 'Restaurant'
radius = 100000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0FPIW43I0WQB4B31BTWLQKS4AZL4UCAYSMVSI1TKGLCTALB5&client_secret=PBQP2BNZO52VJEVFBW34V2WKWYLUZVCCNV1PKUKCU0SE2GYI&ll=41.894802,12.4853384&v=20180604&query=Restaurant&radius=100000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5189f5a197930038f31a44'},
#  'response': {'venues': [{'id': '4ecf948799114b48871e473e',
#     'name': 'Daruma Sushi Restaurant - Parlamento',
#     'location': {'address': 'Piazza del Parlamento 37',
#      'lat': 41.90237766323422,
#      'lng': 12.477739044595266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.90237766323422,
#        'lng': 12.477739044595266}],
#      'distance': 1052,
#      'postalCode': '00186',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza del Parlamento 37',
#       '00186 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframeRestaurant = json_normalize(venues)
dataframeRestaurant.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...    False
# 5  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...    False
# 6  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 7  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 8  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 9  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...    False
#
#                          id                location.address location.cc  \
# 0  4ecf948799114b48871e473e        Piazza del Parlamento 37          IT
# 1  4adcdacaf964a520a35421e3     34 Via Giovanni Vitelleschi          IT
# ...

# %%
dataframeRestaurant.shape
# Out:
# (30, 19)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframeRestaurant_filtered = dataframeRestaurant.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframeRestaurant_filtered['categories'] = dataframeRestaurant_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframeRestaurant_filtered.columns = [column.split('.')[-1] for column in dataframeRestaurant_filtered.columns]

dataframeRestaurant_filtered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-3fd88fdc5394> in <module>
#       1 # keep only columns that include venue name, and anything that is associated with location
# ----> 2 filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
#       3 dataframeRestaurant_filtered = dataframeRestaurant.loc[:, filtered_columns]
#       4
#       5 # function that extracts the category of the venue
#
# NameError: name 'dataframe' is not defined

# %%
dataframeRestaurant_filtered.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-17072faca985> in <module>
# ----> 1 dataframeRestaurant_filtered.name
#
# NameError: name 'dataframeRestaurant_filtered' is not defined

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframeRestaurant_filtered.lat, dataframeRestaurant_filtered.lng, dataframeRestaurant_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-a8915565be76> in <module>
#      13
#      14 # add the Italian restaurants as blue circle markers
# ---> 15 for lat, lng, label in zip(dataframeRestaurant_filtered.lat, dataframeRestaurant_filtered.lng, dataframeRestaurant_filtered.categories):
#      16     folium.features.CircleMarker(
#      17         [lat, lng],
#
# NameError: name 'dataframeRestaurant_filtered' is not defined

# %% [markdown]
# Search for Interest Venue III SPA

# %%
search_query = 'Centro benessere'
radius = 100000
print(search_query + ' .... OK!')
# Out:
# Centro benessere .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0FPIW43I0WQB4B31BTWLQKS4AZL4UCAYSMVSI1TKGLCTALB5&client_secret=PBQP2BNZO52VJEVFBW34V2WKWYLUZVCCNV1PKUKCU0SE2GYI&ll=41.894802,12.4853384&v=20180604&query=Centro benessere&radius=100000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d51206d86bc49002cba2b2d'},
#  'response': {'venues': [{'id': '4d69443b4c463704e3d39fb3',
#     'name': 'IssanThai - Centro Benessere Thailandese',
#     'location': {'address': 'Via Raffaele Cadorna, 17/19',
#      'lat': 41.90846,
#      'lng': 12.4981,
#      'labeledLatLngs': [{'label': 'display', 'lat': 41.90846, 'lng': 12.4981}],
#      'distance': 1851,
#      'postalCode': '00187',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Raffaele Cadorna, 17/19',
#       '00187 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565597805',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframeCentro = json_normalize(venues)
dataframeCentro.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...    False
# 2  [{'id': '54541900498ea6ccd0202697', 'name': 'H...    False
# 3  [{'id': '4f04aa0c2fb6e1c99f3db0b8', 'name': 'N...    False
# 4  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 5  [{'id': '4f04aa0c2fb6e1c99f3db0b8', 'name': 'N...    False
# 6  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...    False
# 7  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...    False
# 8  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...    False
# 9  [{'id': '4bf58dd8d48988d10c951735', 'name': 'C...    False
#
#                          id                    location.address location.cc  \
# 0  4d69443b4c463704e3d39fb3         Via Raffaele Cadorna, 17/19          IT
# 1  51abca9aabd861b91f94eafc                     Via Pandosia 58          IT
# ...

# %%
dataframeCentro.shape
# Out:
# (30, 17)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframeCentro_filtered = dataframeCentro.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframeCentro_filtered['categories'] = dataframeCentro_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframeCentro_filtered.columns = [column.split('.')[-1] for column in dataframeCentro_filtered.columns]

dataframeCentro_filtered
# Out:
#                                                  name  \
# 0            IssanThai - Centro Benessere Thailandese
# 1                            Centro Benessere Armonja
# 2                            Centro Benessere Relaxa’
# 3                              Nefer centro benessere
# 4   Centro Benessere Psicofisico Savasana - Ass. C...
# 5                              Centro Benessere Magda
# 6                           Centro Benessere Sabotino
# 7                   Centro Benessere Saint Tropez Spa
# 8                            Centro Benessere Roma Ok
# 9                      Centro Benessere Giorgio Nardi
# 10                              Centro Benessere Ojas
# 11                                Centro Benessere Mg
# 12                          Angelica Centro Benessere
# 13                                   centro benessere
# 14                           Centro Benessere Ikebana
# 15                                   Centro benessere
# ...

# %%
dataframeCentro_filtered.name
# Out:
# 0              IssanThai - Centro Benessere Thailandese
# 1                              Centro Benessere Armonja
# 2                              Centro Benessere Relaxa’
# 3                                Nefer centro benessere
# 4     Centro Benessere Psicofisico Savasana - Ass. C...
# 5                                Centro Benessere Magda
# 6                             Centro Benessere Sabotino
# 7                     Centro Benessere Saint Tropez Spa
# 8                              Centro Benessere Roma Ok
# 9                        Centro Benessere Giorgio Nardi
# 10                                Centro Benessere Ojas
# 11                                  Centro Benessere Mg
# 12                            Angelica Centro Benessere
# 13                                     centro benessere
# 14                             Centro Benessere Ikebana
# 15                                     Centro benessere
# 16                           Più Bella Centro benessere
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframeCentro_filtered.lat, dataframeCentro_filtered.lng, dataframeCentro_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Rome"
page = requests.get(url)

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of tourist attractions in Rome - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_tourist_attractions_in_Rome","wgTitle":"List of tourist attractions in Rome","wgCurRevisionId":904886760,"wgRevisionId":904886760,"wgArticleId":24912769,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: Archived copy as title","Webarchive template wayback links","All articles with dead external links","Articles with dead external links from January 2018","Articles with permanently dead external links","Tourist attractions in Rome","Tourism in Rome","Rome-related lists","Lists of tourist attractions by city","Metropoli
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of tourist attractions in Rome - Wikipedia
#   </title>
#   <script>
# ...

# %%
search_query = 'Museum'
radius = 100000
print(search_query + ' .... OK!')
# Out:
# Museum .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0FPIW43I0WQB4B31BTWLQKS4AZL4UCAYSMVSI1TKGLCTALB5&client_secret=PBQP2BNZO52VJEVFBW34V2WKWYLUZVCCNV1PKUKCU0SE2GYI&ll=41.894802,12.4853384&v=20180604&query=Museum&radius=100000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d5127529ba3e50032917f19'},
#  'response': {'venues': [{'id': '52de9905498ea199532bee34',
#     'name': 'Vespa Museum',
#     'location': {'lat': 41.893622943283106,
#      'lng': 12.489146755549458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.893622943283106,
#        'lng': 12.489146755549458}],
#      'distance': 341,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d181941735',
#       'name': 'Museum',
#       'pluralName': 'Museums',
#       'shortName': 'Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1565599570',
#     'hasPerk': False},
#    {'id': '4b6fe570f964a5204fff2ce3',
#     'name': 'Musei Vaticani (Musea Vaticana)',
#     'location': {'address': 'Viale Vaticano',
#      'lat': 41.90512773363736,
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframeM = json_normalize(venues)
dataframeM.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d181941735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d18f941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d18f941735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d181941735', 'name': 'M...    False
# 4  [{'id': '4f04b08c2fb6e1c99f3db0bd', 'name': 'T...    False
# 5  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...    False
# 6                                                 []    False
# 7  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...    False
# 8  [{'id': '4bf58dd8d48988d18f941735', 'name': 'A...    False
# 9  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...    False
#
#                          id           location.address location.cc  \
# 0  52de9905498ea199532bee34                        NaN          IT
# 1  4b6fe570f964a5204fff2ce3             Viale Vaticano          VA
# 2  4adcdac6f964a520f95221e3   Piazza del Campidoglio 1          IT
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframeM_filtered = dataframeM.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframeM_filtered['categories'] = dataframeM_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframeM_filtered.columns = [column.split('.')[-1] for column in dataframeM_filtered.columns]

dataframeM_filtered
# Out:
#                                                  name          categories  \
# 0                                        Vespa Museum              Museum
# 1                     Musei Vaticani (Musea Vaticana)          Art Museum
# 2                                    Musei Capitolini          Art Museum
# 3              VIGAMUS - The Videogame Museum of Rome              Museum
# 4               Vatican museum tours - tourinrome.com       Travel Agency
# 5                      Virtual Museum of Ancient Rome      History Museum
# 6                                        Vespa Museum                None
# 7                                    Gladiator Museum      History Museum
# 8                                     Roma wax museum          Art Museum
# 9      Foundling Wheel—Santo Spirito Hospital  Museum      History Museum
# 10                            Botanical Garden Museum    Botanical Garden
# 11                               Museo Pio-Clementino              Museum
# ...

# %%
dataframeM_filtered.name
# Out:
# 0                                          Vespa Museum
# 1                       Musei Vaticani (Musea Vaticana)
# 2                                      Musei Capitolini
# 3                VIGAMUS - The Videogame Museum of Rome
# 4                 Vatican museum tours - tourinrome.com
# 5                        Virtual Museum of Ancient Rome
# 6                                          Vespa Museum
# 7                                      Gladiator Museum
# 8                                       Roma wax museum
# 9        Foundling Wheel—Santo Spirito Hospital  Museum
# 10                              Botanical Garden Museum
# 11                                 Museo Pio-Clementino
# 12                                Museo Ebraico di Roma
# 13                                      Museum Pizzeria
# 14    Palazzo Massimo Alle Terme - Museo Nazionale R...
# 15                                 capital museum tours
# 16                              Cimitero dei Cappuccini
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframeM_filtered.lat, dataframeM_filtered.lng, dataframeM_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
